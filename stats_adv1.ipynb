# %% [markdown]
# # Question1: Define the z-statistic and explain its relationship to the standard normal distribution. How is the z-statistic used in hypothesis testing?
#
# The z-statistic is a standardized score that indicates how many standard deviations a data point (or sample mean) is from the population mean under the assumption that the population follows a normal distribution. It is calculated using the formula:
#
#   z=x-mean/std
# Relationship to the Standard Normal Distribution:
#
# The z-statistic follows a standard normal distribution (mean = 0, standard deviation = 1) when the underlying population is normally distributed or when the sample size is sufficiently large (typically
# 𝑛
# ≥
# 30
# n≥30). This allows for the use of z-tables to find probabilities and critical values associated with the z-statistic.
# In hypothesis testing, the z-statistic helps determine whether to reject the null hypothesis based on the comparison between the calculated z-statistic and critical values from the standard normal distribution:
#
# Formulate Hypotheses: Set up a null hypothesis  H0 and an alternative hypothesis  H1
#
# Calculate the z-statistic: Based on the sample data and the assumptions about the population.
#
# Determine the significance level Common choices are 0.05 or 0.01.
#
# Find the critical value: Use the z-table to identify the z-value that corresponds to the chosen significance level.

# %% [markdown]
# # Question2 : What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is very small (e.g., 0.01)?
#
# A p-value (probability value) is a statistical measure that helps to determine the strength of the evidence against the null hypothesis (H)
#  in hypothesis testing. It represents the probability of obtaining test results at least as extreme as the observed results, assuming that the null hypothesis is true.
#
#  Use in Hypothesis Testing
# Formulate Hypotheses: Establish the null hypothesis H0 and the alternative hypothesis H1
#
# Calculate the Test Statistic: Based on your data, calculate a test statistic (like a z-statistic or t-statistic).
#
# Compute the p-value: The p-value is derived from the test statistic and tells you how extreme your data is under the null hypothesis.
#
# Compare the p-value to the significance level:
#
# If the p-value is less than or equal to
# 𝛼
# α (commonly set at 0.05 or 0.01), you reject the null hypothesis, suggesting that the observed effect is statistically significant.
# If the p-value is greater than
# 𝛼
# α, you do not reject the null hypothesis, indicating insufficient evidence to conclude that there is an effect.
#
#
# nterpretation of a Very Small p-value (e.g., 0.01)
# If the p-value is very small, such as 0.01, it indicates that there is only a 1% probability of observing the data (or something more extreme) if the null hypothesis is true. This small p-value suggests strong evidence against the null hypothesis, leading to the following conclusions:
#
# Reject H0 : There is significant evidence to suggest that the alternative hypothesis H1  ) is true.
#
#
#
#
#
#
# Practical Significance: A small p-value suggests that the observed effect is unlikely to be due to random chance, which may imply that the findings are meaningful in a practical context.
# However, it’s important to remember that a small p-value does not measure the size or importance of the effect; it simply indicates the strength of the evidence against H0

# %% [markdown]
# # Question3: Compare and contrast the binomial and Bernoulli distributions.
#
# The Bernoulli and binomial distributions are both discrete probability distributions that describe random experiments with binary outcomes. Here’s a comparison and contrast of the two:
#
# Bernoulli Distribution
# Definition: The Bernoulli distribution models a single trial with two possible outcomes: success (usually coded as 1) and failure (coded as 0).
#
# Binomial Distribution
# Definition: The binomial distribution models the number of successes in n independent Bernoulli trials (each with the same probability of success
# 𝑝
#
#
# Parameters: It has two parameters:  n(number of trials) p (each with the same probability of success
# 𝑝
#
# Key Differences
# Number of Trials:
#
# Bernoulli: Represents a single trial.
# Binomial: Represents multiple trials (n trials).
# Outcomes:
#
# Bernoulli: Two outcomes (success or failure).
# Binomial: Counts the number of successes in
# 𝑛
#
# Use Cases:
#
# Bernoulli: Used for experiments with one trial (e.g., flipping a coin once).
# Binomial: Used for experiments with multiple trials (e.g., flipping a coin multiple times and counting the number of heads).

# %% [markdown]
# # Question 4: Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli distribution?
#
# The binomial distribution is used under specific conditions that reflect a series of independent experiments with binary outcomes. Here are the conditions required for the binomial distribution to apply:
#
# Conditions for Binomial Distribution
# Fixed Number of Trials: The experiment consists of a fixed number of trials, denoted as
# 𝑛
# n.
#
# Binary Outcomes: Each trial results in one of two outcomes: success (often coded as 1) or failure (coded as 0).
#
# Constant Probability: The probability of success, denoted as
# 𝑝
# p, remains constant for each trial.
#
# Independent Trials: The outcome of each trial is independent of the outcomes of other trials. The result of one trial does not affect the results of others.
#
# Relationship to the Bernoulli Distribution
# The binomial distribution is directly related to the Bernoulli distribution in that it can be viewed as a sum of multiple Bernoulli trials. Here’s how they are connected:
#
# Bernoulli Distribution as a Building Block: Each individual trial in a binomial distribution can be modeled as a Bernoulli distribution. Thus, if you consider one trial, it follows a Bernoulli distribution with parameter
# 𝑝
# p.
#
# Summing Bernoulli Trials: The binomial distribution represents the sum of the results from
# 𝑛
# n independent Bernoulli trials. If you have
# 𝑛
# n independent Bernoulli trials, each with the same probability of success
# 𝑝
# p, the total number of successes across those trials follows a binomial distribution.

# %% [markdown]
# # Question5: What are the key properties of the Poisson distribution, and when is it appropriate to use this distribution
#
# The Poisson distribution is a discrete probability distribution that models the number of events occurring in a fixed interval of time or space. Here are the key properties and appropriate usage conditions for the Poisson distribution:
#
# Key Properties of the Poisson Distribution
# Parameter: The Poisson distribution is characterized by a single parameter
# 𝜆
# λ (lambda), which represents the average rate of occurrence of the event in the given interval.
#
#
# Mean=λ
# Variance=λ
#
# Memorylessness: The Poisson distribution has the property of "independence" in increments, meaning that the number of events in non-overlapping intervals is independent.
#
# Count of Events: It models the count of events that occur in a fixed interval, which can be time, distance, area, etc.
#
# Skewness: The distribution is skewed, especially for smaller values of
# 𝜆
# λ, but it approaches a normal distribution as
# 𝜆
# λ increases.
#
#
# When to Use the Poisson Distribution
# The Poisson distribution is appropriate under the following conditions:
#
# Rare Events: It is suitable for modeling the number of rare events in a given interval. For example, the number of phone calls received at a call center in an hour or the number of decay events per unit time from a radioactive source.
#
# Independence: Events should occur independently of each other. The occurrence of one event does not affect the probability of another event occurring.
#
# Constant Rate: The average rate (
# 𝜆
# λ) at which events occur should be constant across the interval being considered.
#
# Discrete Count: The variable of interest is a count (non-negative integer) of events that can occur.

# %% [markdown]
# # Question6: Define the terms "probability distribution" and "probability density function" (PDF). How does a PDF differ from a probability mass function (PMF)?
#
# Probability Distribution
# A probability distribution describes how the probabilities of a random variable are distributed across its possible values. It provides a comprehensive view of the likelihood of different outcomes in a random experiment. Probability distributions can be classified into two main types:
#
# Discrete Probability Distribution: Deals with discrete random variables that take on a countable number of values (e.g., rolling a die).
# Continuous Probability Distribution: Deals with continuous random variables that can take on any value within a given range (e.g., measuring the height of individuals).
#
# Probability Density Function (PDF)
# A probability density function (PDF) is a function that describes the likelihood of a continuous random variable taking on a specific value. The PDF must satisfy two key properties:
#
# The area under the PDF curve over the entire space is equal to 1.
# The probability of the variable falling within a specific interval can be found by calculating the area under the curve over that interval.
#
#
# Difference Between PDF and PMF
# The key differences between a probability density function (PDF) and a probability mass function (PMF) are as follows:
#
# Type of Random Variable:
#
# PMF: Used for discrete random variables. It gives the probability that a discrete random variable is exactly equal to a specific value.
# PDF: Used for continuous random variables. It does not provide the probability of a variable being exactly equal to a specific value (which is always zero) but rather gives the density of probability at that point.

# %% [markdown]
# # Question7: Explain the Central Limit Theorem (CLT) with example.
#
# The Central Limit Theorem (CLT) is a fundamental concept in statistics that states that, regardless of the original distribution of a population, the distribution of the sample means will approach a normal distribution as the sample size becomes larger (typically
# 𝑛
# ≥
# 30
# n≥30). This holds true as long as the samples are independent and identically distributed (i.i.d.).
#
# Key Points of the Central Limit Theorem
# Sample Means: The CLT specifically pertains to the distribution of sample means.
# Normality: As the sample size increases, the sampling distribution of the mean becomes approximately normal, even if the original population distribution is not.
#
# Mean and Variance:
# The mean of the sampling distribution (the mean of the sample means) will equal the population mean (
# 𝜇
# μ).
# The variance of the sampling distribution will equal the population variance divided by the sample size (
# 𝜎
# 2
# /
# 𝑛
# σ
# 2
#  /n), where
# 𝜎
# σ is the population standard deviation.
# Example of the Central Limit Theorem
# Scenario:
# Imagine you have a population of students in a school, and their heights are not normally distributed (for example, the distribution may be skewed due to a higher number of younger students).
#
# Population Mean (
# 𝜇
# μ): 160 cm
# Population Standard Deviation (
# 𝜎
# σ): 10 cm
# Sampling:
# Take Samples: You decide to take random samples of size
#
# n=
# 30
# n=30 from this population.
# Calculate Sample Means: For each sample, calculate the mean height.
# Repeat: Repeat this process multiple times (say, 1000 samples).
# Result:
# According to the CLT, as you calculate the means of these samples, the distribution of the sample means will approximate a normal distribution centered around the population mean of 160 cm.
#
# Conclusion:
# Even if the original distribution of heights is not normal, the distribution of the sample means will be approximately normal due to the Central Limit Theorem. This allows for the application of normal distribution techniques, such as hypothesis testing and confidence intervals, to make inferences about the population mean based on the sample means.

# %% [markdown]
# # Question8: Compare z-scores and t-scores. When should you use a z-score, and when should a t-score be a pplied instead?
#
# Z-scores and t-scores are both standardized scores used in statistics to determine how far a data point is from the mean in terms of standard deviations. However, they are used in different contexts and have distinct properties.
#
# Z-scores
# Definition: A z-score indicates how many standard deviations a data point is from the mean of the population
#
# Use Case: Z-scores are typically used when:
#
# The population standard deviation (
# 𝜎
# σ) is known.
# The sample size is large (usually
# 𝑛
# ≥
# 30
# n≥30), due to the Central Limit Theorem.
# The data are normally distributed.
# T-scores
# Definition: A t-score is similar to a z-score but is used when the population standard deviation is unknown. It adjusts for the additional uncertainty that comes with estimating the standard deviation from a sample.
#
# Use Case: T-scores are typically used when:
#
# The population standard deviation is unknown.
# The sample size is small (usually
# 𝑛
# <
# 30
# n<30).
# The data are normally distributed or approximately normal.
# Key Differences
# Population Standard Deviation:
#
# Z-score: Requires knowledge of the population standard deviation.
# T-score: Used when the population standard deviation is unknown and is estimated from the sample.
# Sample Size:
#
# Z-score: More reliable with larger sample sizes (n ≥ 30).
# T-score: More appropriate for smaller sample sizes (n < 30).
# Distribution:
#
# Z-score: Follows the standard normal distribution (mean = 0, standard deviation = 1).
# T-score: Follows the t-distribution, which has heavier tails than the normal distribution, allowing for greater variability in small samples.

# %%
 # Question9: Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample
# size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to reject the null hypothesis?


# Task: Write Python code to calculate the z-score and p-value for the given data Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.


import scipy.stats as stats

# Given data
sample_mean = 105
population_mean = 100
std_dev = 15
sample_size = 25
significance_level = 0.05

# Calculate the z-score
z_score = (sample_mean - population_mean) / (std_dev / (sample_size ** 0.5))

# Calculate the p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Output the results
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {p_value:.4f}")

# Hypothesis testing decision
if p_value < significance_level:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Z-score: 1.6667
# P-value: 0.0956
# Fail to reject the null hypothesis.

# %%
# Question10: Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.
# Generate 1,000 samples and plot the distribution. What is the expected mean and variance?

# Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.

# Objective: Understand the properties of a binomial distribution and verify them through simulation.
